# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedebeed555/pandas/blob/main/25JulListingDataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/listings.csv')

# %%
df
# Out:
#                       id                                       listing_url  \
# 0                2992450              https://www.airbnb.com/rooms/2992450
# 1                3820211              https://www.airbnb.com/rooms/3820211
# 2                5651579              https://www.airbnb.com/rooms/5651579
# 3                6623339              https://www.airbnb.com/rooms/6623339
# 4                9005989              https://www.airbnb.com/rooms/9005989
# ..                   ...                                               ...
# 442  1419803505997334256  https://www.airbnb.com/rooms/1419803505997334256
# 443  1430417055174000914  https://www.airbnb.com/rooms/1430417055174000914
# 444  1432823196473666155  https://www.airbnb.com/rooms/1432823196473666155
# 445  1434108183586713709  https://www.airbnb.com/rooms/1434108183586713709
# 446  1434112653259573474  https://www.airbnb.com/rooms/1434112653259573474
#
#           scrape_id last_scraped       source  \
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  4.470000e+02  4.470000e+02  4.470000e+02           447.000000
# mean   7.590596e+17  2.025061e+13  2.509316e+08            42.434004
# std    5.182807e+17  7.821254e-03  2.002203e+08           227.069357
# min    2.992450e+06  2.025061e+13  6.576000e+04             1.000000
# 25%    5.311787e+07  2.025061e+13  4.762598e+07             2.000000
# 50%    9.289489e+17  2.025061e+13  2.329679e+08             4.000000
# 75%    1.192345e+18  2.025061e+13  4.306940e+08            11.000000
# max    1.434113e+18  2.025061e+13  6.804113e+08          2159.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed    latitude  \
# count                 447.000000                           0.0  447.000000
# mean                   62.384787                           NaN   42.658487
# std                   346.175206                           NaN    0.010478
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                       id                                       listing_url  \
# 0                2992450              https://www.airbnb.com/rooms/2992450
# 1                3820211              https://www.airbnb.com/rooms/3820211
# 2                5651579              https://www.airbnb.com/rooms/5651579
# 3                6623339              https://www.airbnb.com/rooms/6623339
# 4                9005989              https://www.airbnb.com/rooms/9005989
# ..                   ...                                               ...
# 442  1419803505997334256  https://www.airbnb.com/rooms/1419803505997334256
# 443  1430417055174000914  https://www.airbnb.com/rooms/1430417055174000914
# 444  1432823196473666155  https://www.airbnb.com/rooms/1432823196473666155
# 445  1434108183586713709  https://www.airbnb.com/rooms/1434108183586713709
# 446  1434112653259573474  https://www.airbnb.com/rooms/1434112653259573474
#
#           scrape_id last_scraped       source  \
# ...

# %%
df.shape
# Out:
# (447, 79)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 79, dtype: object

# %%
#Missing value per column
df.isnull().sum()
# Out:
# id                                               0
# listing_url                                      0
# scrape_id                                        0
# last_scraped                                     0
# source                                           0
#                                                 ..
# calculated_host_listings_count                   0
# calculated_host_listings_count_entire_homes      0
# calculated_host_listings_count_private_rooms     0
# calculated_host_listings_count_shared_rooms      0
# reviews_per_month                               67
# Length: 79, dtype: int64

# %%
#percentage of missing values
(df.isnull().sum()/len(df))*100
# Out:
# id                                               0.000000
# listing_url                                      0.000000
# scrape_id                                        0.000000
# last_scraped                                     0.000000
# source                                           0.000000
#                                                   ...
# calculated_host_listings_count                   0.000000
# calculated_host_listings_count_entire_homes      0.000000
# calculated_host_listings_count_private_rooms     0.000000
# calculated_host_listings_count_shared_rooms      0.000000
# reviews_per_month                               14.988814
# Length: 79, dtype: float64

# %%
# now drop reviews_per_month column
df.drop('reviews_per_month',axis=1,inplace=True)

# %%
df = df.drop(['reviews_per_month'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-56-3684702610.py in <cell line: 0>()
# ----> 1 df = df.drop(['reviews_per_month'], axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
MyCoumnsList=(df.columns.tolist())

# %%
MyCoumnsList

# %%
df

# %%
df.drop('name',axis=1,inplace=True)

# %%
df.drop('listing_url',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            447 non-null    int64
#  1   listing_url                                   447 non-null    object
#  2   scrape_id                                     447 non-null    int64
#  3   last_scraped                                  447 non-null    object
#  4   source                                        447 non-null    object
#  5   name                                          447 non-null    object
#  6   description                                   437 non-null    object
#  7   neighborhood_overview                         198 non-null    object
#  8   picture_url                                   447 non-null    object
# ...

# %%
df['price'].replace('[\$,]', '', regex=True, inplace=True)

# %%
df['price']
# Out:
# 0       70.00
# 1      100.00
# 2       75.00
# 3       95.00
# 4       86.00
#         ...
# 442    120.00
# 443    150.00
# 444    107.00
# 445     57.00
# 446     61.00
# Name: price, Length: 447, dtype: object

# %%
df[['price','minimum_nights','availability_365']].describe()
# Out:
#              price  minimum_nights  availability_365
# count   415.000000      447.000000        447.000000
# mean    121.004819        6.684564        226.626398
# std     126.004102       19.718792        116.905740
# min      24.000000        1.000000          0.000000
# 25%      68.000000        1.000000        149.000000
# 50%      93.000000        2.000000        250.000000
# 75%     131.500000        3.000000        332.500000
# max    1486.000000      365.000000        365.000000

# %%
df['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 447 entries, 0 to 446
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 415 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
df[['price','minimum_nights','availability_365']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             415 non-null    float64
#  1   minimum_nights    447 non-null    int64
#  2   availability_365  447 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 10.6 KB

# %% [markdown]
# Here, i wanted to convert the 'price' column to float

# %%
df['price']=df['price'].astype(float)

# %%
df=df[df['price']<=1000]

# %%
df['price']
# Out:
# 0       70.0
# 1      100.0
# 2       75.0
# 3       95.0
# 4       86.0
#        ...
# 442    120.0
# 443    150.0
# 444    107.0
# 445     57.0
# 446     61.0
# Name: price, Length: 412, dtype: float64

# %%
df=df[df['minimum_nights']<=365]

# %%
df['minimum_nights']
# Out:
# 0      28
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 442     7
# 443     1
# 444    28
# 445     1
# 446     1
# Name: minimum_nights, Length: 412, dtype: int64

# %%
df['availability_365'].describe()
# Out:
# count    412.000000
# mean     234.689320
# std      110.932217
# min        0.000000
# 25%      159.000000
# 50%      253.500000
# 75%      334.000000
# max      365.000000
# Name: availability_365, dtype: float64

# %%
df=df[df['availability_365']<=365]
df=df[df['availability_365']>0]

# %%
df['availability_365'].describe()
# Out:
# count    409.000000
# mean     236.410758
# std      109.491908
# min        1.000000
# 25%      159.000000
# 50%      256.000000
# 75%      334.000000
# max      365.000000
# Name: availability_365, dtype: float64

# %%
df
# Out:
#                       id                                       listing_url  \
# 0                2992450              https://www.airbnb.com/rooms/2992450
# 1                3820211              https://www.airbnb.com/rooms/3820211
# 2                5651579              https://www.airbnb.com/rooms/5651579
# 3                6623339              https://www.airbnb.com/rooms/6623339
# 4                9005989              https://www.airbnb.com/rooms/9005989
# ..                   ...                                               ...
# 442  1419803505997334256  https://www.airbnb.com/rooms/1419803505997334256
# 443  1430417055174000914  https://www.airbnb.com/rooms/1430417055174000914
# 444  1432823196473666155  https://www.airbnb.com/rooms/1432823196473666155
# 445  1434108183586713709  https://www.airbnb.com/rooms/1434108183586713709
# 446  1434112653259573474  https://www.airbnb.com/rooms/1434112653259573474
#
#           scrape_id last_scraped       source  \
# ...

# %%
df['neighborhood_overview']
# Out:
# 0                                                    NaN
# 1      Great restaurants, architecture, walking, peop...
# 2      The neighborhood is very eclectic. We have a v...
# 3      Located in Albany's finest urban neighborhood,...
# 4      There are many shops, restaurants, bars, museu...
#                              ...
# 442                                                  NaN
# 443                                                  NaN
# 444                                                  NaN
# 445                                                  NaN
# 446                                                  NaN
# Name: neighborhood_overview, Length: 409, dtype: object

# %%
df['neighbourhood_group'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'neighbourhood_group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-91-1888910638.py in <cell line: 0>()
# ----> 1 df['neighbourhood_group'].unique()
#
# ...

# %%
df['neighbourhood_group']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'neighbourhood_group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-92-2456848187.py in <cell line: 0>()
# ----> 1 df['neighbourhood_group']
#
# ...

# %%
df.drop('listing_url',axis=1,inplace=True)

# %%
df.drop('picture_url',axis=1,inplace=True)

# %%
df.drop('host_url',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-102-3773986618.py in <cell line: 0>()
# ----> 1 df.drop('host_url',axis=1,inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.drop('host_name',axis=1,inplace=True)

# %%
df
# Out:
#                       id       scrape_id last_scraped       source  \
# 0                2992450  20250609011619   2025-06-09  city scrape
# 1                3820211  20250609011619   2025-06-09  city scrape
# 2                5651579  20250609011619   2025-06-09  city scrape
# 3                6623339  20250609011619   2025-06-09  city scrape
# 4                9005989  20250609011619   2025-06-09  city scrape
# ..                   ...             ...          ...          ...
# 442  1419803505997334256  20250609011619   2025-06-09  city scrape
# 443  1430417055174000914  20250609011619   2025-06-09  city scrape
# 444  1432823196473666155  20250609011619   2025-06-09  city scrape
# 445  1434108183586713709  20250609011619   2025-06-09  city scrape
# 446  1434112653259573474  20250609011619   2025-06-09  city scrape
#
#                                                  name  \
# 0                          Luxury 2 bedroom apartment
# ...
